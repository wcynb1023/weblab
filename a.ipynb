# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - why use git and not use code_sharing google-docs?
# > independent copy of the code , people disrupt each other
# - many copies in different machine , complex control ?
# - two person modify one file but different place , how to merge together?

# %% [markdown]
# - one people want to revert , how perfectly sync ?

# %% [markdown]
# - a lots of version , which one is the most up-to-date?

# %% [markdown]
# ### everyone have full copy and history (track change)
# ### distributed not centralized

# %% [markdown]
# 1. git init
# 2. git status

# %% [markdown]
# ##  two stage
# - not track real time  (will cost more)
#
# 1. git add
# 2. git commit
